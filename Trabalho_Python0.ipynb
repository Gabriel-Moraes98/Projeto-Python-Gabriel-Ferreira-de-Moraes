# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriel-Moraes98/aula-tabela/blob/main/Trabalho_Python0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nome: Gabriel Ferreira de Moraes
#
# Matrícula: 2020200156
#
# Turma: EAD222175
#
# Curso: Desenvolvimento de Software Multiplataforma
#
# Data: 17/11/2022

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# Este repositório de dados foi criado em 01/11/1990, pelo Vision Group na Universidade de Massachusetts, com o objetivo no qual as instâncias foram sorteadas aleatoriamente de um banco de dados de 7 imagens externas. As imagens foram segmentadas manualmente para criar uma classificação para cada pixel. Onde cada instância é uma região 3x3.

# %%
csv_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/image/segmentation.data'

# %%
df = pd.read_csv(csv_url, skiprows=2, index_col=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   return func(*args, **kwargs)

# %%
df.head(5)
# Out:
#   REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# 0           BRICKFACE                140.0               125.0
# 1           BRICKFACE                188.0               133.0
# 2           BRICKFACE                105.0               139.0
# 3           BRICKFACE                 34.0               137.0
# 4           BRICKFACE                 39.0               111.0
#
#    SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# 0                     9                   0.0         0.0  0.277778
# 1                     9                   0.0         0.0  0.333333
# 2                     9                   0.0         0.0  0.277778
# 3                     9                   0.0         0.0  0.500000
# 4                     9                   0.0         0.0  0.722222
#
#    HEDGE-MEAN  HEDGE-SD  INTENSITY-MEAN  RAWRED-MEAN  RAWBLUE-MEAN  \
# 0    0.062963  0.666667        0.311111     6.185185      7.333334
# ...

# %%
df.shape
# Out:
# (210, 19)

# %%
import pandas as pd
pd.set_option('display.max_columns', 19)
df
# Out:
#     REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# 0             BRICKFACE                140.0               125.0
# 1             BRICKFACE                188.0               133.0
# 2             BRICKFACE                105.0               139.0
# 3             BRICKFACE                 34.0               137.0
# 4             BRICKFACE                 39.0               111.0
# ..                  ...                  ...                 ...
# 205               GRASS                 36.0               243.0
# 206               GRASS                186.0               218.0
# 207               GRASS                197.0               236.0
# 208               GRASS                208.0               240.0
# 209               GRASS                223.0               185.0
#
#      SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# 0                       9              0.000000         0.0  0.277778
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   REGION-CENTROID-COL   210 non-null    object
#  1   REGION-CENTROID-ROW   210 non-null    float64
#  2   REGION-PIXEL-COUNT    210 non-null    float64
#  3   SHORT-LINE-DENSITY-5  210 non-null    int64
#  4   SHORT-LINE-DENSITY-2  210 non-null    float64
#  5   VEDGE-MEAN            210 non-null    float64
#  6   VEDGE-SD              210 non-null    float64
#  7   HEDGE-MEAN            210 non-null    float64
#  8   HEDGE-SD              210 non-null    float64
#  9   INTENSITY-MEAN        210 non-null    float64
#  10  RAWRED-MEAN           210 non-null    float64
#  11  RAWBLUE-MEAN          210 non-null    float64
#  12  RAWGREEN-MEAN         210 non-null    float64
#  13  EXRED-MEAN            210 non-null    float64
# ...

# %%
df.describe()
# Out:
#        REGION-CENTROID-ROW  REGION-PIXEL-COUNT  SHORT-LINE-DENSITY-5  \
# count           210.000000          210.000000                 210.0
# mean            124.647619          122.757143                   9.0
# std              74.104024           58.139686                   0.0
# min               1.000000           11.000000                   9.0
# 25%              60.500000           81.500000                   9.0
# 50%             123.500000          121.500000                   9.0
# 75%             189.750000          174.500000                   9.0
# max             252.000000          250.000000                   9.0
#
#        SHORT-LINE-DENSITY-2  VEDGE-MEAN    VEDGE-SD  HEDGE-MEAN    HEDGE-SD  \
# count            210.000000  210.000000  210.000000  210.000000  210.000000
# mean               0.008466    0.006349    1.925132    5.719529    2.604233
# std                0.029549    0.030077    3.158211   43.495942    4.798268
# ...

# %%
df.isnull().sum()
# Out:
# REGION-CENTROID-COL     0
# REGION-CENTROID-ROW     0
# REGION-PIXEL-COUNT      0
# SHORT-LINE-DENSITY-5    0
# SHORT-LINE-DENSITY-2    0
# VEDGE-MEAN              0
# VEDGE-SD                0
# HEDGE-MEAN              0
# HEDGE-SD                0
# INTENSITY-MEAN          0
# RAWRED-MEAN             0
# RAWBLUE-MEAN            0
# RAWGREEN-MEAN           0
# EXRED-MEAN              0
# EXBLUE-MEAN             0
# EXGREEN-MEAN            0
# VALUE-MEAN              0
# SATURATION-MEAN         0
# HUE-MEAN                0
# dtype: int64

# %%
HUE = df[["HUE-MEAN"]].dropna()
display(HUE)
# Out:
#      HUE-MEAN
# 0    0.545635
# 1    0.538580
# 2    0.532628
# 3    0.573633
# 4    0.562919
# ..        ...
# 205  0.452229
# 206  0.401347
# 207  0.292729
# 208  0.421621
# 209  0.445418
#
# [210 rows x 1 columns]

# %%
HUE.plot.hist()

# %% [markdown]
# Com este trabalho posso concluir que Pandas é uma biblioteca para uso em Python, open-source e de uso gratuito, que fornece ferramentas para análise e manipulação de dados. Ainda Alinhamento automático ou explícito dos dados, tratamento flexível e simplificado de dados ausentes, uso de operações, combinações e operações relacionais, informações estatísticas, séries temporais e visualização de dados.
# Inclusive como o Pandas engloba algumas funcionalidades da biblioteca matplotlib, ela permite que os usuários criem visualizações simplificadas dos dados.
